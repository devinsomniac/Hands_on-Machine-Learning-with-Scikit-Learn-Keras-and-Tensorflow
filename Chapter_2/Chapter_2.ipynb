# %%
import pandas as pd

# %%
housing = pd.read_csv('../Data/housing.csv')

# %%
#Reads first 5 column of the dataset
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#It shows the count of each column and the Data Type 
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
#It says the count of each category in a column
housing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
#It shows the summary of the numerical attributes
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#Another way to get desciption of the data you are dealing with is to plot

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50,figsize = (12,8))
plt.show()

# %%
#Create a test data lke 20% of data set for testing of the model
# We can create this using selection of data randomly from the dataset

# %%
#We need numpy as it is a library to manupulate numerical data
import numpy as np
def shuffle_and_split_data(data,test_ratio):
    shuffle_indices = np.random.permutation(len(data))
    test_size = int(len(data) * test_ratio)
    test_indices = shuffle_indices[:test_size]
    train_indices = shuffle_indices[test_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
train_set,test_set = shuffle_and_split_data(housing,0.2)

# %%
len(train_set)
# Out:
# 16512

# %%
len(test_set)
# Out:
# 4128

# %%
len(housing)
# Out:
# 20640

# %%
#Adding indices in the df
housing_with_id = housing.reset_index()

# %%
housing_with_id.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity income_cat
# 0        NEAR BAY          5
# 1        NEAR BAY          5
# 2        NEAR BAY          5
# ...

# %%
len(train_set)
# Out:
# 16512

# %%
len(test_set)
# Out:
# 4128

# %%
housing_with_id["median_income"].hist(bins=50,figsize = (12,8))
plt.show()

# %%
housing_with_id["income_cat"] = pd.cut(housing_with_id["median_income"],bins=[0.,1.5,3.0,4.5,6.,np.inf],labels=[1,2,3,4,5])

# %%
housing_with_id.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity income_cat
# 0        NEAR BAY          5
# 1        NEAR BAY          5
# 2        NEAR BAY          5
# ...

# %%
housing_with_id["income_cat"].value_counts().sort_index().plot.bar(rot=45,grid=True)
plt.xlabel("Income category")
plt.ylabel("Number of Districts")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
strat_train_set,strat_test_set = train_test_split(housing_with_id, test_size = 0.2 , stratify=housing_with_id["income_cat"],random_state=42)

# %%
len(strat_train_set)
# Out:
# 16512

# %%
len(strat_test_set)
# Out:
# 4128

# %%
strat_test_set["income_cat"].value_counts()/len(strat_test_set)
# Out:
# income_cat
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: count, dtype: float64

# %%
strat_test_set.head()
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 5241    5241    -118.39     34.12                29.0       6447.0
# 17352  17352    -120.42     34.89                24.0       2020.0
# 3505    3505    -118.45     34.25                36.0       1453.0
# 7777    7777    -118.10     33.91                35.0       1653.0
# 14155  14155    -117.07     32.77                38.0       3779.0
#
#        total_bedrooms  population  households  median_income  \
# 5241           1012.0      2184.0       960.0         8.2816
# 17352           307.0       855.0       283.0         5.0099
# 3505            270.0       808.0       275.0         4.3839
# 7777            325.0      1072.0       301.0         3.2708
# 14155           614.0      1495.0       614.0         4.3529
#
#        median_house_value ocean_proximity income_cat
# 5241             500001.0       <1H OCEAN          5
# 17352            162500.0       <1H OCEAN          4
# ...

# %%
strat_train_set.head()
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 12655  12655    -121.46     38.52                29.0       3873.0
# 15502  15502    -117.23     33.09                 7.0       5320.0
# 2908    2908    -119.04     35.37                44.0       1618.0
# 14053  14053    -117.13     32.75                24.0       1877.0
# 20496  20496    -118.70     34.28                27.0       3536.0
#
#        total_bedrooms  population  households  median_income  \
# 12655           797.0      2237.0       706.0         2.1736
# 15502           855.0      2015.0       768.0         6.3373
# 2908            310.0       667.0       300.0         2.8750
# 14053           519.0       898.0       483.0         2.2264
# 20496           646.0      1837.0       580.0         4.4964
#
#        median_house_value ocean_proximity income_cat
# 12655             72100.0          INLAND          2
# 15502            279600.0      NEAR OCEAN          5
# ...

# %%
housing_with_id = strat_train_set.copy()

# %%
len(housing_with_id)
# Out:
# 16512

# %%
housing_with_id.plot(kind = "scatter" , x ="longitude" , y = "latitude" , grid = True, alpha = 0.2)
plt.show()

# %%
housing_with_id.plot(
    kind="scatter",
    x="longitude",
    y="latitude",
    grid=True,
    s=housing_with_id["population"] / 100,
    label="population",
    c="median_house_value",
    cmap="jet",
    colorbar=True,
    legend=True,
    sharex=False,
    figsize=(20, 7)
)

plt.show()

# %%
housing_with_id = housing_with_id.drop(columns=['ocean_proximity'])

# %%
corr_matrix = housing_with_id.corr()

# %%
corr_matrix["median_house_value"].sort_values(ascending = False)
# Out:
# median_house_value    1.000000
# median_income         0.687151
# income_cat            0.642256
# total_rooms           0.135140
# housing_median_age    0.114146
# index                 0.067805
# households            0.064590
# total_bedrooms        0.047781
# population           -0.026882
# longitude            -0.047466
# latitude             -0.142673
# Name: median_house_value, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ["median_house_value","median_income","total_rooms","housing_median_age"]
scatter_matrix(housing_with_id[attributes], figsize=(12,8))
plt.show()

# %%
housing_with_id.plot(kind="scatter",x="median_income", y = "median_house_value", alpha = 0.2, grid = True)
plt.show()
